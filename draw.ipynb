# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the data from the files
data_1 = np.load('log/test1/tower.test.reward.0.npy')
data_2 = np.load('log/test2/tower.test.reward.0.npy')
data_3 = np.load('log/test3/tower.test.reward.0.npy')
# Plotting the data
plt.figure(figsize=(10, 5))
plt.plot(data_1, label='baselines', marker='o', color='red')
plt.plot(data_2, label='Noise2', marker='o', color='green')
plt.plot(data_3, label='Noise4', marker='o', color='blue')


# Adding labels and title
plt.xlabel('Data Point Index')
plt.ylabel('Value')
plt.title('Line Plot of Two Data Sets')

# Adding legend
plt.legend()

# Showing the plot
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[33], line 5
#       2 import matplotlib.pyplot as plt
#       4 # Load the data from the files
# ----> 5 data_1 = np.load('log/test1/tower.test.reward.0.npy')
#       6 data_2 = np.load('log/test2/tower.test.reward.0.npy')
#       7 data_3 = np.load('log/test3/tower.test.reward.0.npy')
#
# File ~/anaconda3/envs/mario/lib/python3.8/site-packages/numpy/lib/npyio.py:405, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     403     own_fid = False
#     404 else:
# --> 405     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     406     own_fid = True
#     408 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'log/test1/tower.test.reward.0.npy'

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the data from the files
data_1 = np.load('log/IID_base_GRADER_causal_chemistry_collider/tower.test.reward.0.npy')
data_2 = np.load('log/IID_noise_GRADER_causal_chemistry_collider/tower.test.reward.0.npy')
# Plotting the data
plt.figure(figsize=(10, 5))
plt.plot(data_1, label='baselines', marker='o', color='red')
plt.plot(data_2, label='Noise', marker='o', color='green')


# Adding labels and title
plt.xlabel('Data Point Index')
plt.ylabel('Value')
plt.title('Line Plot of Two Data Sets')

# Adding legend
plt.legend()

# Showing the plot
plt.grid(True)
plt.show()
